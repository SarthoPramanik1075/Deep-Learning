# %% [markdown]
# <a href="https://colab.research.google.com/github/SarthoPramanik1075/Deep-Learning/blob/main/DL_Final_Exam_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DL Final Exam
#
# **Name:** Sartho Pramanik
#
# **Course Email:** pramaniksartho1@gmail.com
#
#
# ## End of Assignment
#
# Before submitting:
# - Run all cells from top to bottom.
# - Check that all answer sections are filled.
# - Instruction video অনুযায়ী আমাদের দেয়া Colab ফাইলটি থেকে প্রথম একটি Save copy in drive করে নিবা। এরপর Google colab এর মধ্যে কোডগুলো করবে এবং সেই ফাইলটি ‘Anyone with the link’ & ‘View’ Access দিয়ে ফাইলটির Shareble Link টি সাবমিট করবে।

# %% [markdown]
# # Question 01: [ Marks 10 ]
#
# ## Explain the concept of backpropagation in detail. Describe how the error is propagated from the output layer to the hidden layers. Derive the mathematical expressions for weight updates using the chain rule, and explain how learning rate affects the training process.

# %% [markdown]
# # Write Answer 01:

# %% [markdown]
# #
# #Backpropagation
#
# Backpropagation is the learning process of a neural network. It helps the network reduce error by updating weights.
#
# Steps:
#
# 1. Forward pass → network gives prediction
# 2. Calculate loss/error
# 3. Backward pass → error moves backward
# 4. Update weights using gradient descent
#
# #Weight update:
#
# w_new = w_old − η(∂L/∂w)
#
# #Where:
#
# η = learning rate
#
# Learning rate controls update size.
#
# i) Small learning rate → slow learning
#
# ii) Large learning rate → unstable learning
#
# So, backpropagation helps the model learn better by minimizing error.
# #
#
#
#
#
# ![Screenshot 2026-05-08 at 10.35.08 PM.png](data:image/png;base64,...)![Screenshot 2026-05-08 at 10.35.28 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Question 02: [ Marks 10 ]
#
# ## Consider a neural network with one hidden layer using sigmoid activation. Derive the complete backpropagation equations for updating weights and biases. Show all steps clearly, including forward pass, loss calculation, and backward pass.

# %% [markdown]
# ## Write Answer 02:

# %% [markdown]
# #
# #Backpropagation with One Hidden Layer
#
# #Forward pass:
#
# z1 = W1X + b1
#
# a1 = sigmoid(z1)
#
# z2 = W2a1 + b2
#
# ŷ = sigmoid(z2)
#
# #Loss:
#
# L = 1/2(y − ŷ)^2
#
# #Backward pass:
#
# #Output error:
#
# δ2 = (ŷ − y) × ŷ(1 − ŷ)
#
# #Hidden error:
#
# δ1 = (W2^T × δ2) × a1(1 − a1)
#
# #Weight update:
#
# W = W − η(gradient)
#
# Thus, the network updates weights to reduce loss.
# #

# %% [markdown]
# # Question 03: [Marks 5]
#
# ## Discuss the vanishing gradient problems in deep neural networks. Explain why they occur during backpropagation, how activation functions contribute to this issue, and suggest at least three techniques to overcome these problems.

# %% [markdown]
# ## Write Answer 03:

# %% [markdown]
# #
# #Vanishing Gradient Problem
#
# Vanishing gradient happens when gradients become very small during backpropagation.
#
# As a result:
#
#  1. Early layers learn slowly
#  2. Training becomes difficult
#
# #Main causes:
#
# 1. Sigmoid activation
# 2. Tanh activation
#
# #Solutions:
#
# 1. ReLU activation
# 2. Batch normalization
# 3. Proper weight initialization
# 4. Residual connections
#
# ReLU is commonly used because it helps gradients flow better.
# #

# %% [markdown]
# # Question 04: [ Marks 5 ]
#
# ## Describe the architecture of an Artificial Neural Network (ANN) in detail. Explain the role of each component (neurons, weights, bias, activation functions). Also discuss how increasing the number of hidden layers and neurons affects model performance and overfitting.

# %% [markdown]
# ## Write Answer 04:

# %% [markdown]
# #
# #Architecture of ANN
#
# ANN has mainly 3 layers:
#
#  1. Input layer
#  2. Hidden layer
#  3. Output layer
#
# Neuron calculation:
#
# z = wx + b
#
# Main components:
#
#  1. Neuron
#  2. Weight
#  3. Bias
#  4. Activation function
#
# #Increasing hidden layers and neurons:
#
# Advantages:
#
# Learns complex patterns
# Better performance
#
# #Disadvantages:
#
# More computation
# Overfitting risk
# Longer training time
# #

# %% [markdown]
# # Question 05: [ Marks 10 ]
#
# ## Compare Artificial Neural Networks (ANN) and Convolutional Neural Networks (CNN) in detail. Discuss their architectures, working principles, advantages, limitations, and typical use cases such as image processing, tabular data, and pattern recognition.

# %% [markdown]
# ## Write Answer 05:

# %% [markdown]
# #
# ##ANN vs CNN
# #ANN
# i. Fully connected network
# ii. Good for tabular data
# iii. High number of parameters
# #CNN
# 1. Specially designed for images
# 2. Uses convolution and pooling
# 3. Automatically extracts features
#
# #Advantages of CNN:
#
# 1. Better image performance
# 2. Fewer parameters
# 3. Preserves spatial information
#
# #Applications:
#
# 1. Image classification
# 2. Face recognition
# 3. Object detection
#
# CNN is more effective than ANN for image-related tasks.
# #

# %% [markdown]
# # Question 06: [ Marks 10 ]
#
# ## Explain different activation functions used in neural networks, including Sigmoid, Tanh, and ReLU. Provide their mathematical formulas, advantages, disadvantages, and suitable use cases. Also discuss why ReLU is widely used in deep learning.

# %% [markdown]
# ## Write Answer 06:

# %% [markdown]
# #
# #Activation Functions
#
# Activation functions add non-linearity.
#
# #Sigmoid
#
# Output: 0 to 1
#
# #Advantages:
#
# Good for probability
#
# #Disadvantages:
#
# Vanishing gradient problem
# #Tanh
#
# #Output: −1 to 1
#
# #Advantages:
#
# Zero-centered
#
# #Disadvantages:
#
# Vanishing gradient
# #ReLU
#
# f(x) = max(0,x)
#
# #Advantages:
#
# Fast training.
#
# Less vanishing gradient.
#
# #Disadvantages:
#
# Dead neuron problem
#
# ReLU is mostly used in modern CNNs.
# #

# %% [markdown]
# # Question 07: [ Marks 10 ]
#
# ## Describe the convolution operation in CNNs in detail. Explain how filters (kernels) work, how feature maps are generated, and how parameters like stride and padding affect the output. Provide a step-by-step example using a small input matrix.
# Note :  You've to attach an image here.

# %% [markdown]
# ## Write Answer 07:

# %% [markdown]
# # Question 08: [ Marks 10 ]
#
# ## Explain the concept of pooling in CNNs. Compare MaxPooling and AveragePooling in terms of operation, advantages, and impact on feature extraction. Discuss how pooling helps in reducing overfitting and computational complexity.

# %% [markdown]
# Write Answer 08:

# %% [markdown]
# #
# #Pooling in CNN
#
# Pooling reduces feature map size.
#
# #Types:
#
# 1. MaxPooling
# 2. AveragePooling
# 3. MaxPooling
# 4. Takes maximum value
# 5. Preserves strong features
# 6. AveragePooling
# 7. Takes average value
# 8. Produces smoother output
#
# #Benefits of pooling:
#
# Reduces computation.
#
# Reduces overfitting.
#
# Speeds up training.
# #

# %% [markdown]
# # Question 09: [ Marks 10 ]
#
# ## Given an input image of size 128×128×3, explain step-by-step how the dimensions change after multiple convolution and pooling layers. Clearly show calculations for output size after each layer using appropriate formulas.

# %% [markdown]
# # Write Answer 09:

# %% [markdown]
# #
# #CNN Dimension Changes
#
# Input: 128 × 128 × 3
#
# After Conv1: 128 × 128 × 32
#
# After Pool1: 64 × 64 × 32
#
# After Conv2: 64 × 64 × 64
#
# After Pool2: 32 × 32 × 64
#
# After Conv3: 32 × 32 × 128
#
# After Pool3: 16 × 16 × 128
#
# Flatten: 16 × 16 × 128 = 32768
#
# Pooling reduces height and width while convolution increases depth.
# #

# %% [markdown]
# # Question 10: [ Marks 20 ]
#
# ## Design and implement a deep Convolutional Neural Network (CNN) for a multi-class image classification problem using PyTorch. The network should consist of four convolutional blocks, where each block includes two convolution layers followed by activation and normalization, and a pooling layer at the end. The number of filters should increase progressively across blocks. After the convolutional part, flatten the feature maps and connect them to fully connected layers with dropout for regularization, and produce final outputs corresponding to K classes. Also explain the role of each part of the network in detail.

# %% [markdown]
# # Write Answer 10:

# %% [markdown]
# import torch
#
# import torch.nn as nn
#
# class CNN(nn.Module):
#
#     def __init__(self,num_classes):
#
#         super(CNN, self).__init__()
#
#         self.features = nn.Sequential(
#             nn.Conv2d(3, 32, kernel_size=3, padding='same'),
#             nn.ReLU(),
#             nn.BatchNorm2d(32),
#             nn.MaxPool2d(2),
#             nn.Conv2d(32, 64, kernel_size=3, padding='same'),
#             nn.ReLU(),
#             nn.BatchNorm2d(64),
#             nn.MaxPool2d(2),
#         )
#
#         self.classifier = nn.Sequential(
#             nn.Flatten(),
#             nn.Linear(64*32*32,128),
#             nn.ReLU(),
#             nn.Dropout(0.5),
#             nn.Linear(128,num_classes)
#         )
#
#     def forward(self,x):
#         x = self.features(x)
#         x = self.classifier(x)
#         return x
#
#
# #Explanation:
#
# Convolution → feature extraction
#
# ReLU → adds non-linearity
#
# Pooling → reduces size
#
# Dropout → prevents overfitting
#
# Fully connected layer → final classification
#
# This CNN model can be used for image classification tasks.
